# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Installing client, langchain, openai

# %%
# !pip install weaviate-client
# !pip install langchain
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
# ...

# %% [markdown]
# API Keys

# %%
OPENAI_API_KEY = "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"
WEAVIATE_API_KEY = "GsSa4iizVnBtM2v4OIxiS8vtgYMuWKAxtDhH"
WEAVIATE_CLUSTER = "https://chatbot-x2hoprg1.weaviate.network"

# %% [markdown]
# ## Data reading from directory

# %%
# !mkdir data

# %%
# !pip install unstructured
# !pip install "unstructured[pdf]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.9/457.9 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 35.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 43.0 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=770260934766b8a35251bebe55c75a178093f4912bd5cec8daf32e23703c11b2
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 81.1 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import DirectoryLoader

loader = DirectoryLoader("./data",glob = "**/*.pdf")
data = loader.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
#data

# %% [markdown]
# Text splitting

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
docs = text_splitter.split_documents(data)

# %%
#docs

# %% [markdown]
# Embedding

# %%
from langchain.embeddings.openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(openai_api_key= OPENAI_API_KEY)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x78ba5b822470>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x78ba5b84d390>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %% [markdown]
# ## Store in vector database

# %%
import weaviate
from langchain.vectorstores import Weaviate

#Connect to weaviate Cluster
auth_config = weaviate.auth.AuthApiKey(api_key = WEAVIATE_API_KEY)
WEAVIATE_URL = WEAVIATE_CLUSTER

client = weaviate.Client(
    url = WEAVIATE_URL,
    additional_headers = {"X-OpenAI-Api-key": OPENAI_API_KEY},
    auth_client_secret = auth_config,
    startup_period = 10
)

# %%
client.is_ready()
# Out:
# True

# %%
# define input structure
client.schema.delete_all()
client.schema.get()
schema = {
    "classes": [
        {
            "class": "Chatbot",
            "description": "Documents for chatbot",
            "vectorizer": "text2vec-openai",
            "moduleConfig": {"text2vec-openai": {"model": "ada", "type": "text"}},
            "properties": [
                {
                    "dataType": ["text"],
                    "description": "The content of the paragraph",
                    "moduleConfig": {
                        "text2vec-openai": {
                            "skip": False,
                            "vectorizePropertyName": False,
                        }
                    },
                    "name": "content",
                },
            ],
        },
    ]
}

client.schema.create(schema)
vectorstore = Weaviate(client, "Chatbot", "content", attributes=["source"])

# %%
# load text into the vectorstore
text_meta_pair = [(doc.page_content, doc.metadata) for doc in docs]
texts, meta = list(zip(*text_meta_pair))
vectorstore.add_texts(texts, meta)
# Out:
# ['96844f50-a575-460f-b355-e5dd488c9206',
#  '7127062f-3af5-456f-a7d3-2ff8e7e209e5',
#  '6f7f65ac-11be-4c50-ad7e-bd3658aaa3b3',
#  '919dc64c-2361-4e5f-a47e-698257f1b79e',
#  '066c55ef-46c5-426f-a0b0-6e70c2969397',
#  '30e1d193-a869-47d2-b56e-a0633c35e65d',
#  'dac0118f-d467-4d5f-9006-341d1f707003',
#  '85760d93-3b9b-4d20-96e1-7432d793af21',
#  '9c745094-3c20-4422-9838-b2a87a647f20',
#  'b8471294-7905-464a-bbce-f7877e96db4f',
#  'f5011edf-8deb-42fe-8659-ab3fefb1212e',
#  'c5cf318e-5781-48b4-9836-ded96bf5dc7e',
#  '3cdb31ab-9888-4471-ad70-b7bd377b010d',
#  'f8d44836-d896-40d4-9d35-e587434c483c',
#  '03ecae51-617c-4e51-b3fe-5d104215e245',
#  '4f93af20-6608-40c8-9236-d410848166cc',
#  '4b6b7712-2161-4ff8-8f9a-a05b60bf87d2',
#  'c54f7645-9031-4e17-a022-ab4ca9256d2e',
#  'b95ebde2-023c-499d-a536-0b86c1811591',
#  '6e87712e-a2dd-468a-8fcc-e0505d0d165a',
#  '94b671fd-3c50-44a4-b0d4-041680f5c34e',
#  '05f221d1-9f6b-420c-addb-f13c614fbffa',
#  '527ade84-1711-4ae9-a7f9-d599f01ba6e5',
# ...

# %% [markdown]
# Similarity

# %%
query = "what is a yolo?"

# retrieve text related to the query
docs = vectorstore.similarity_search(query, top_k=20)

# %%
docs
# Out:
# [Document(page_content='[37] Joseph Redmon, Santosh Divvala, Ross Girshick, and Ali Farhadi. You only look once: Unified, real-time object de- tection. In Proceedings of the IEEE conference on computer vision and pattern recognition, pages 779–788, 2016. [38] Joseph Redmon and Ali Farhadi. Yolo9000: better, faster, stronger. In Proceedings of the IEEE conference on computer vision and pattern recognition, pages 7263–7271, 2017. [39] Joseph Redmon and Ali Farhadi. Yolov3: An incremental improvement. arXiv preprint arXiv:1804.02767, 2018. [40] Shaoqing Ren, Kaiming He, Ross Girshick, and Jian Sun. Faster r-cnn: Towards real-time object detection with region proposal networks. Advances in neural information process- ing systems, 28:91–99, 2015.\n\n[41] Zhenfeng Shao, Congmin Li, Deren Li, Orhan Altan, Lei Zhang, and Lin Ding. An accurate matching method for pro- jecting vector data into surveillance video to monitor and ISPRS Int. J. Geo Inf., 9(7):448, protect cultivated land. 2020.', 
# ...

# %% [markdown]
# ## Open AI

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
# define chain
chain = load_qa_chain(
    OpenAI(openai_api_key = OPENAI_API_KEY,temperature=0),
    chain_type="stuff")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
# create answer
chain.run(input_documents=docs, question=query)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ' YOLO (You Only Look Once) is a real-time object detection algorithm that can detect multiple objects in an image and classify them into different categories. It is a popular one-stage detector that has been improved upon in various versions, such as YOLOv2, YOLOv3, and YOLOv4.'

# %%
query = "yolo architecture"

# retrieve text related to the query
docs = vectorstore.similarity_search(query, top_k=20)

# %%
chain.run(input_documents=docs, question=query)
# Out:
# ' The YOLO (You Only Look Once) architecture is a unified, real-time object detection system that was first introduced in 2016 by Joseph Redmon, Santosh Divvala, Ross Girshick, and Ali Farhadi. It has since been improved upon with the release of YOLO9000 in 2017 and YOLOv3 in 2018. The architecture uses a backbone network, a neck structure, and transformer prediction heads to detect objects in images. It has been used in various computer vision tasks, including surveillance and drone-captured images.'

# %%
query = "features of Yolo architecture"

# retrieve text related to the query
docs = vectorstore.similarity_search(query, top_k=20)

# %%
chain.run(input_documents=docs, question=query)
# Out:
# ' The YOLOv5 architecture uses CSPDarknet53 as the backbone, PANet as the Neck, and YOLO detection head. It also includes four TPHs (transformer prediction heads) that use feature maps from transformer encoder blocks in the Neck. Additionally, the architecture uses bag of freebies and specials to optimize performance and includes multi-scale testing and multi-model ensemble strategies during inference. A self-trained classifier (ResNet18) is also used to improve classification ability.'

# %%
query = "key points"

# retrieve text related to the query
docs = vectorstore.similarity_search(query, top_k=20)

# %%
chain.run(input_documents=docs, question=query)
# Out:
# ' The key points mentioned in this context are the different components of an object detection framework, such as backbone, neck, and head. Other key points include the use of different networks for feature extraction, the importance of the neck in utilizing features, and the use of additional strategies such as CBAM, ms-testing, and model ensemble for better detection results.'
